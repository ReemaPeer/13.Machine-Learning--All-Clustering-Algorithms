# %%
# importing the required libraries

import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

# %%
# Reading the file

dataset = pd.read_csv('Mall_Customers.csv')
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
# Getting the input data coloumns

x = dataset.iloc[:,[3,4]].values
x
# Out:
# array([[ 15,  39],
#        [ 15,  81],
#        [ 16,   6],
#        [ 16,  77],
#        [ 17,  40],
#        [ 17,  76],
#        [ 18,   6],
#        [ 18,  94],
#        [ 19,   3],
#        [ 19,  72],
#        [ 19,  14],
#        [ 19,  99],
#        [ 20,  15],
#        [ 20,  77],
#        [ 20,  13],
#        [ 20,  79],
#        [ 21,  35],
#        [ 21,  66],
#        [ 23,  29],
#        [ 23,  98],
#        [ 24,  35],
#        [ 24,  73],
#        [ 25,   5],
#        [ 25,  73],
#        [ 28,  14],
#        [ 28,  82],
#        [ 28,  32],
#        [ 28,  61],
#        [ 29,  31],
#        [ 29,  87],
#        [ 30,   4],
#        [ 30,  73],
#        [ 33,   4],
#        [ 33,  92],
#        [ 33,  14],
#        [ 33,  81],
#        [ 34,  17],
#        [ 34,  73],
#        [ 37,  26],
#        [ 37,  75],
#        [ 38,  35],
#        [ 38,  92],
#        [ 39,  36],
#        [ 39,  61],
#        [ 39,  28],
#        [ 39,  65],
#        [ 40,  55],
# ...

# %%
# Creating the OPTICS clustering model

from sklearn.cluster import OPTICS
cluster_optics = OPTICS(min_samples = 5, cluster_method = 'xi', algorithm='auto')
y_pred = cluster_optics.fit_predict(x)
y_pred
# Out:
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:441: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   old_joblib = LooseVersion(joblib_version) < LooseVersion('0.12')
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# C:\Users\reema\anaconda3\envs\aiml\lib\site-packages\sklearn\neighbors\base.py:737: DeprecationWarning: distutils Version classes are deprecated. Use packaging.version instead.
#   if LooseVersion(joblib_version) < LooseVersion('0.12'):
# ...

# %%
dir(cluster_optics)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_estimator_type',
#  '_get_param_names',
#  '_get_tags',
#  'algorithm',
#  'cluster_hierarchy_',
#  'cluster_method',
#  'core_distances_',
#  'eps',
#  'fit',
#  'fit_predict',
#  'get_params',
#  'labels_',
#  'leaf_size',
#  'max_eps',
#  'metric',
#  'metric_params',
#  'min_cluster_size',
#  'min_samples',
#  'n_jobs',
#  'ordering_',
#  'p',
#  'predecessor_',
#  'predecessor_correction',
#  'reachability_',
#  'set_params',
#  'xi']

# %%
# Identifying the number of clusters

labels = cluster_optics.labels_
n_clusters = len(np.unique(labels))-1
print("No. of clusters are: ",n_clusters)
# Out:
# No. of clusters are:  11

# %%
# Evaluating the cluster using the silhouette score

from sklearn.metrics import silhouette_score
s_score = silhouette_score(x,y_pred)
s_score
# Out:
# 0.035688157101128805

# %%
# Creating the table with the cluster output

dataset['Cluster_group'] = y_pred
dataset
# Out:
#      CustomerID   Genre  Age  Annual Income (k$)  Spending Score (1-100)  \
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
#      Cluster_group
# 0               -1
# 1                5
# 2                8
# ...

# %%
# Viewing the clusters

colors = plt.cm.rainbow(np.linspace(0, 1, n_clusters))
plt.scatter(x[:, 0], x[:, 1], c=colors[y_pred], s=40, marker='o')
plt.title('OPTICS Clustering')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()

# %%
colors = ['red','green','blue','yellow','purple','maroon','orange','teal','violet','pink','olive','tan','cyan','#CD7F32']
plt.figure(figsize=(6,6))
plt.scatter(x[:,0], x[:,1], c= y_pred, s = 40, cmap = matplotlib.colors.ListedColormap(colors) )
plt.title('OPTICS Clustering')
plt.xlabel('Annual Income')
plt.ylabel('Spending Score')
plt.show()
